# %%
import os
import sys
import subprocess
import pandas as pd
from matplotlib import pyplot as plt

# %%
dataset_folder = "../../datasets/synthetic/transactional/"
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)
files = os.listdir(dataset_folder)
print(files)
if len(files) == 0:
    print("No files found in the dataset folder")
    generate_files = "../../utils/file_create.sh"
    os.system(generate_files)

files = os.listdir(dataset_folder)

# remove parquet files
files = [f for f in files if f.endswith(".csv")]

# sort files
files.sort()
# Out:
# ['triangle_700M.csv', 'triangle_800M.parquet', 'triangle_1100M.parquet', 'triangle_1000M.csv', 'triangle_1100M.csv', 'triangle_1000M.parquet', 'square_1024M.parquet', 'square_1024M.csv', 'triangle_800M.csv', 'triangle_700M.parquet', 'square_3072M.csv', 'square_3072M.parquet', 'triangle_900M.parquet', 'square_2048M.parquet', 'triangle_1200M.parquet', 'triangle_1200M.csv', 'square_2048M.csv', 'triangle_900M.csv', 'cufile.log']

# %%
result_folder = "../../results/file_read"
if not os.path.exists(result_folder):
    os.makedirs(result_folder)
result_file = os.path.join(result_folder, "file_read.csv")

# %%
import cudf

def csv_to_parquet(file, parquet_file):
    df = cudf.read_csv(file)
    pandas_df = df.to_pandas()
    pandas_df.to_parquet(parquet_file)
    del df
    del pandas_df

# %%
from cudf_read import cudf_read
from gpu_read import gpu_read
from pandas_read import pandas_read
from python_read import python_read

cpp_executable = "./parallel_read"  # Path to the compiled C++ executable
delimiter = ","  # Define the delimiter to be used by the C++ program

# Check if the result file exists
if os.path.exists(result_file):
    # Load existing results into a DataFrame
    df = pd.read_csv(result_file)
else:
    # Create a new DataFrame with specified columns if the result file does not exist
    df = pd.DataFrame(columns=["file", "method", "time", "memory"])
    df.to_csv(result_file, index=False)

# Iterate over the list of files to process
# for file in files:
for method in ["cudf-csv", "cudf-parquet", "gpu-csr", "1-thread Read", "8-thread Read"]:
    for file in files:
    # print(file)  # Print the current file being processed
    
    # Iterate over the different methods to process the file
    # for method in ["pandas", "cudf", "gpu-csr", "python", "cpp"]:
    # for method in ["cudf-csv", "cudf-parquet", "gpu-csr", "cpp-1", "cpp-8"]:
        obj = None  # Initialize the object variable for each method

        # Instantiate the appropriate reader object based on the method
        if method == "pandas":
            obj = pandas_read(dataset_folder + file)
        elif method == "cudf-csv":
            obj = cudf_read(dataset_folder + file)
        elif method == "cudf-parquet":
            parquet_file = dataset_folder + file
            parquet_file = parquet_file.replace(".csv", ".parquet")
            if not os.path.exists(parquet_file):
                csv_to_parquet(dataset_folder + file, parquet_file)
                
            # print parquet_file size
            print(f"Parquet file size: {os.path.getsize(parquet_file) / 1024 / 1024:.2f} MB")
            obj = cudf_read(parquet_file)
        elif method == "gpu-csr":
            obj = gpu_read(dataset_folder + file, ',')
        elif method == "python":
            obj = python_read(dataset_folder + file)

        # Check if the file-method combination has already been processed
        if len(df[(df["file"] == file) & (df["method"] == method)]) > 0:
            print(f"\tSkipping {file} with method {method}")  # Skip processing if already done
            continue

        print(f"\tProcessing {file} with method {method}")

        if method == "1-thread Read":
            num_cores = 1  # Number of cores to be used for parallel processing
            method = "1-thread Read"
            
            if len(df[(df["file"] == file) & (df["method"] == method)]) > 0:
                print(f"\tSkipping {file} with method {method}")
                continue
                
            try:
                # Run the C++ executable with necessary arguments and capture its output
                result = subprocess.run(
                    [cpp_executable, dataset_folder + file, delimiter, str(num_cores)],
                    capture_output=True, text=True
                )

                # Parse the output from the C++ program
                output_lines = result.stdout.strip().split("\n")
                runtime_line = next(line for line in output_lines if "Total time" in line)
                # memory_line = next(line for line in output_lines if "Memory used" in line)
                peak_memory_line = next(line for line in output_lines if "Peak memory (total process):" in line)

                # Extract runtime and memory usage from the parsed lines
                runtime = float(runtime_line.split(":")[-1].strip().split()[0])
                # memory = int(float(memory_line.split(":")[-1].strip().split()[0]) * 1024) 
                memory = int(float(peak_memory_line.split(":")[-1].strip().split()[0]) * 1024)

            except Exception as e:
                # Print an error message if the subprocess fails
                print(f"\tError running C++ method for {file}: {e}")
                continue
        elif method == "8-thread Read":
            num_cores = 8  # Number of cores to be used for parallel processing
            method = "8-thread Read"
            
            # if already processed, skip
            if len(df[(df["file"] == file) & (df["method"] == method)]) > 0:
                print(f"\tSkipping {file} with method {method}")
                continue

            try:
                # Run the C++ executable with necessary arguments and capture its output
                result = subprocess.run(
                    [cpp_executable, dataset_folder + file, delimiter, str(num_cores)],
                    capture_output=True, text=True
                )

                # Parse the output from the C++ program
                output_lines = result.stdout.strip().split("\n")
                runtime_line = next(line for line in output_lines if "Total time" in line)
                # memory_line = next(line for line in output_lines if "Memory used" in line)
                peak_memory_line = next(line for line in output_lines if "Peak memory (total process):" in line)

                # Extract runtime and memory usage from the parsed lines
                runtime = float(runtime_line.split(":")[-1].strip().split()[0])
                # memory = int(float(memory_line.split(":")[-1].strip().split()[0]) * 1024) 
                memory = int(float(peak_memory_line.split(":")[-1].strip().split()[0]) * 1024)

            except Exception as e:
                # Print an error message if the subprocess fails
                print(f"\tError running C++ method for {file}: {e}")
                continue
        else:
            # For Python-based methods, perform the read operation and gather metrics
            print(f"\tReading {file} with method {method}")
            obj.read()  # Execute the read operation
            runtime = obj.get_runtime()  # Get the runtime of the operation
            custom_memory = obj.get_custom_memory()  # Get the memory usage details

            # Extract memory usage based on the method type (CPU or GPU)
            if method in ["gpu-csr", "cudf-csv", "cudf-parquet"]:
                memory = int(custom_memory.get("gpu", 0))  # GPU memory usage
            else:
                memory = int(custom_memory.get("cpu", 0))  # CPU memory usage

        del obj  # Delete the object to free memory

        # Create a new row with the file, method, runtime, and memory usage details
        new_row = pd.DataFrame([[file, method, runtime, memory]], columns=["file", "method", "time", "memory"])
        df = pd.concat([df, new_row], ignore_index=True)  # Append the new row to the DataFrame

        # Save the updated DataFrame to the result CSV file after each iteration
        df.to_csv(result_file, index=False)
# Out:
# 	Skipping square_1024M.csv with method cudf-csv
# 	Skipping square_2048M.csv with method cudf-csv
# 	Skipping square_3072M.csv with method cudf-csv
# 	Skipping triangle_1000M.csv with method cudf-csv
# 	Skipping triangle_1100M.csv with method cudf-csv
# 	Skipping triangle_1200M.csv with method cudf-csv
# 	Skipping triangle_700M.csv with method cudf-csv
# 	Skipping triangle_800M.csv with method cudf-csv
# 	Skipping triangle_900M.csv with method cudf-csv
# Parquet file size: 776.56 MB
# 	Skipping square_1024M.csv with method cudf-parquet
# Parquet file size: 1575.04 MB
# 	Skipping square_2048M.csv with method cudf-parquet
# Parquet file size: 2361.14 MB
# 	Skipping square_3072M.csv with method cudf-parquet
# Parquet file size: 812.77 MB
# 	Skipping triangle_1000M.csv with method cudf-parquet
# Parquet file size: 894.17 MB
# 	Skipping triangle_1100M.csv with method cudf-parquet
# Parquet file size: 975.39 MB
# 	Skipping triangle_1200M.csv with method cudf-parquet
# Parquet file size: 568.72 MB
# 	Skipping triangle_700M.csv with method cudf-parquet
# Parquet file size: 650.09 MB
# 	Skipping triangle_800M.csv with method cudf-parquet
# Parquet file size: 731.42 MB
# 	Skipping triangle_900M.csv with method cudf-parquet
# 	Skipping square_1024M.csv with method gpu-csr
# 	Skipping square_2048M.csv with method gpu-csr
# 	Skipping square_3072M.csv with method gpu-csr
# 	Skipping triangle_1000M.csv with method gpu-csr
# 	Skipping triangle_1100M.csv with method gpu-csr
# 	Skipping triangle_1200M.csv with method gpu-csr
# 	Skipping triangle_700M.csv with method gpu-csr
# 	Skipping triangle_800M.csv with method gpu-csr
# 	Skipping triangle_900M.csv with method gpu-csr
# 	Skipping square_1024M.csv with method 1-thread Read
# 	Skipping square_2048M.csv with method 1-thread Read
# 	Skipping square_3072M.csv with method 1-thread Read
# 	Skipping triangle_1000M.csv with method 1-thread Read
# 	Skipping triangle_1100M.csv with method 1-thread Read
# 	Skipping triangle_1200M.csv with method 1-thread Read
# 	Skipping triangle_700M.csv with method 1-thread Read
# 	Skipping triangle_800M.csv with method 1-thread Read
# 	Skipping triangle_900M.csv with method 1-thread Read
# 	Skipping square_1024M.csv with method 8-thread Read
# 	Skipping square_2048M.csv with method 8-thread Read
# 	Skipping square_3072M.csv with method 8-thread Read
# 	Skipping triangle_1000M.csv with method 8-thread Read
# 	Skipping triangle_1100M.csv with method 8-thread Read
# 	Skipping triangle_1200M.csv with method 8-thread Read
# 	Skipping triangle_700M.csv with method 8-thread Read
# 	Skipping triangle_800M.csv with method 8-thread Read
# 	Skipping triangle_900M.csv with method 8-thread Read

# %%
def file_size_to_mib_corrected(file_name):
    try:
        parts = file_name.split("_")
        size_with_unit = parts[1]  # Get the size with the unit
        # remove the extension
        size_with_unit = size_with_unit.split(".")[0]
        size = float(size_with_unit[:-1])  # Extract the numeric part
        unit = size_with_unit[-1]  # Extract the unit (M or G)
        if unit == "M":
            return size
        elif unit == "G":
            return size * 1024  # Convert GiB to MiB
        else:
            return None  # Unexpected unit

    except Exception as e:
        print(f"Error processing file name: {file_name}, Error: {e}")
        return None

df = pd.read_csv(result_file)


# Reapply the corrected function to the dataset
df["size_mib"] = df["file"].apply(file_size_to_mib_corrected)
df["size_mib"] = df["size_mib"].astype(float)
# sort the dataframe by file size
df = df.sort_values(by='size_mib')


# Regroup and plot again
df["shape"] = df["file"].str.split("_").str[0]
shapes = df["shape"].unique()

# convert memory to MiB
df["memory"] = df["memory"] / 1024 / 1024

# round time to 4 decimal places
df["time"] = df["time"].round(4)

fig_size = (4, 4)
time_threshold = 100  # Threshold for runtime

linestyle_tuple = [
     ('loosely dotted',        (0, (1, 10))),
     ('dotted',                (0, (1, 1))),
    #  ('densely dotted',        (0, (1, 1))),
    #  ('long dash with offset', (5, (10, 3))),
     ('loosely dashed',        (0, (5, 10))),
     ('dashed',                (0, (5, 5))),
     ('densely dashed',        (0, (5, 1))),

     ('loosely dashdotted',    (0, (3, 10, 1, 10))),
    #  ('dashdotted',            (0, (3, 5, 1, 5))),
    #  ('densely dashdotted',    (0, (3, 1, 1, 1))),

     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))]

marker_shapes = ['o', 's', '^', 'D', 'v', 'p', '*', 'h', 'H', '+', 'x', 'X']

# get all the unique methods
methods = df["method"].unique()
# assign a color and tuple and marker to each method
line_color_marker = [[linestyle_tuple[i][1], f"C{i}", f"{marker_shapes[i]}"] for i in range(len(methods))]
sorted_methods = sorted(methods)

assignment = {methods[i]: line_color_marker[i] for i in range(len(methods))}

for shape in shapes:
    subset = df[df["shape"] == shape]
    plt.figure(figsize=fig_size)

    for method in sorted_methods:
        if method in subset["method"].unique():
            method_data = subset[subset["method"] == method]

            linestyle, color, marker = assignment[method]
            method_data_below_threshold = method_data[method_data["time"] <= time_threshold]

            plt.plot(
                method_data_below_threshold["size_mib"],
                method_data_below_threshold["time"],
                marker=marker,
                label=method,
                linestyle=linestyle,
                color=color
            )

    plt.xlabel("File Size (MiB)")
    plt.ylabel("Time (seconds)")

    plt.title(f"Runtime for {shape.capitalize()} Files")
    handles, labels = plt.gca().get_legend_handles_labels()
    sorted_handles_labels = sorted(zip(labels, handles), key=lambda x: sorted_methods.index(x[0]))
    sorted_labels, sorted_handles = zip(*sorted_handles_labels)
    plt.legend(sorted_handles, sorted_labels)

    plt.grid(True, which="both", linestyle="--", linewidth=0.5)

    # Add caption as a note
    plt.figtext(0.5, -0.05, "Note: Parquet files are compressed, resulting in smaller file sizes and memory usage.",
                ha="center", fontsize=7, wrap=True)
    
    plt.savefig(result_folder + f"/time_{shape}.png", bbox_inches="tight")

    
for shape in shapes:
    subset = df[df["shape"] == shape]
    plt.figure(figsize=fig_size)

    for method in sorted_methods:
        method_data = subset[subset["method"] == method]
        linestyle, color, marker = assignment[method]
        
        plt.plot(
            method_data["size_mib"],
            method_data["memory"],
            marker=marker,
            label=method,
            linestyle=linestyle,
            color=color
        )

    plt.xlabel("File Size (MiB)")
    plt.ylabel("Memory (MiB)")
    plt.title(f"Peak Memory Usage for {shape.capitalize()} Files")
    plt.legend()
    plt.grid(True, which="both", linestyle="--", linewidth=0.5)

    # Add caption as a note
    plt.figtext(0.5, -0.05, "Note: Parquet files are compressed, resulting in smaller file sizes and memory usage.",
                ha="center", fontsize=7, wrap=True)

    plt.savefig(result_folder + f"/memory_{shape}.png", bbox_inches="tight")
